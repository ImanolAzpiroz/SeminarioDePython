# %% [markdown]
# # Actividades introductorias

# %% [markdown]
# ### Escribe un programa que solicite al usuario su año de nacimiento y muestre en qué año cumplirá 18, 21 y 100 años.

# %%
año_nam = int(input("Ingrese su año de naciemiento: "))

print(f"Cumplira 18 en {año_nam + 18}, 21 en {año_nam + 21} y 100 en {año_nam + 100}")
# Out:
# Cumplira 18 en 19, 21 en 22 y 100 en 101

# %% [markdown]
# ### 2) Escribe un programa que solicite al usuario una cantidad de segundos y muestre cuántas horas, minutos y segundos equivalen. Por ejemplo, 3661 segundos son 1 hora, 1 minuto y 1 segundo

# %%
seconds = int(input("Ingrese una cantidad de segundos"))



hours = seconds // 3660
minutes = (seconds % 3660) // 60
seconds = seconds % 60
print(f"{hours} horas, {minutes} minutos y {seconds} segundos")
# Out:
# 0 horas, 58 minutos y 19 segundos

# %% [markdown]
# ### 3) Crea un programa que solicite al usuario un número y muestre su tabla de multiplicar del 1 al 10 utilizando un bucle for.

# %%
num = int(input("Ingrese un número entero: "))

for n in range(1, 11):
    print(num * n)
# Out:
# 9
# 18
# 27
# 36
# 45
# 54
# 63
# 72
# 81
# 90

# %% [markdown]
# ### 4) Crea un programa que dado un número N ingresado por el usuario, imprima los números del 1 al N pero saltee los múltiplos de 5. Nota: utilizá la sentencia continue donde haga falta.

# %%
num = int(input("Ingrese un número entero: "))

list_num = []
list_mult = []

for n in range(1, num):
    if n % 5 == 0:
        list_num.append(n)
    else:
        list_mult.append(n)   
   
print(list_num)
print(list_mult)
# Out:
# [5, 10, 15, 20, 25]
# [1, 2, 3, 4, 6, 7, 8, 9, 11, 12, 13, 14, 16, 17, 18, 19, 21, 22, 23, 24, 26, 27, 28]

# %% [markdown]
# ### 5) Escribe un programa que simule una caja registradora: el usuario ingresa precios de productos de a uno. Cuando ingresa 0, el programa se detiene y muestra el total acumulado. Nota: utilizá la sentencia break cuando haga falta

# %%
total = 0.0

while True:
    num = float(input("Ingrese un número entero: "))
    if num == 0:
        break
    total += num

print(f"El total es {total}")
# Out:
# El total es 35.5

# %% [markdown]
# ### 7) Escribe un programa que solicite al usuario una lista de palabras. Luego, construí una oración uniendo únicamente las palabras que tengan más de 3 letras, separadas por espacios. Las palabras cortas deben ser excluidas del resultado final

# %%
word_list = input("Ingrese una lista de palabras separadas por espacios: ").split()

sent = ""
for word in word_list:
    if len(word) > 3:
        sent += word + " "

print(sent)
# Out:
# Ingrese lista palabras separadas espacios
