# %%
int_list = [5, 2, 9, 1, 5, 6]

sorted_list = sorted(int_list)
sorted_list_reverse = sorted(int_list, reverse = True)

print(sorted_list)
print(sorted_list_reverse)
# Out:
# [1, 2, 5, 5, 6, 9]
# [9, 6, 5, 5, 2, 1]

# %%
nums = [-10, -3, 5, 2]

sorted_nums = sorted(nums, key = abs)
sorted_nums
