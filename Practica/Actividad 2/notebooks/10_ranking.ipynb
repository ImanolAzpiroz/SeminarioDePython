# %% [markdown]
# ### 10. Simulación de competencia de cocina y ranking
#
# Simule una competencia de cocina donde 5 participantes son evaluados por 3 <br>
# jueces en cada ronda. Cada juez otorga un puntaje del 1 al 10. El puntaje de la <br>
# ronda es la suma de los tres jueces.

# %%
import sys 
# %load_ext autoreload
# %autoreload 2

sys.path.append('../src')

import process_round as pr
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
stats = {
    'Valentina': {'rounds_win': 0, 'total_Score': 0, 'best_score': 0, 'average_Score': 0}, 
    'Mateo': {'rounds_win': 0, 'total_Score': 0, 'best_score': 0, 'average_Score': 0},
    'Camila': {'rounds_win': 0, 'total_Score': 0, 'best_score': 0, 'average_Score': 0},
    'Santiago': {'rounds_win': 0, 'total_Score': 0, 'best_score': 0, 'average_Score': 0},
    'Lucia': {'rounds_win': 0, 'total_Score': 0, 'best_score': 0, 'average_Score': 0}
}

# %%
rounds = [
    {
        'theme': 'Entrada',
        'scores': {
            'Valentina': {'judge_1': 8, 'judge_2': 7, 'judge_3': 9},
            'Mateo': {'judge_1': 7, 'judge_2': 8, 'judge_3': 7},
            'Camila': {'judge_1': 9, 'judge_2': 9, 'judge_3': 8},
            'Santiago': {'judge_1': 6, 'judge_2': 7, 'judge_3': 6},
            'Lucía': {'judge_1': 8, 'judge_2': 8, 'judge_3': 8},
        }
    },
    {
        'theme': 'Plato principal',
        'scores': {
            'Valentina': {'judge_1': 9, 'judge_2': 9, 'judge_3': 8}, 
            'Mateo': {'judge_1': 8, 'judge_2': 7, 'judge_3': 9},
            'Camila': {'judge_1': 7, 'judge_2': 6, 'judge_3': 7},
            'Santiago': {'judge_1': 9, 'judge_2': 8, 'judge_3': 8},
            'Lucía': {'judge_1': 7, 'judge_2': 8, 'judge_3': 7},
        }
    },
    {
        'theme': 'Postre', 
        'scores': {
            'Valentina': {'judge_1': 7, 'judge_2': 8, 'judge_3': 7},
            'Mateo': {'judge_1': 9, 'judge_2': 9, 'judge_3': 8},
            'Camila': {'judge_1': 8, 'judge_2': 7, 'judge_3': 9},
            'Santiago': {'judge_1': 7, 'judge_2': 7, 'judge_3': 6},
            'Lucía': {'judge_1': 9, 'judge_2': 9, 'judge_3': 9},
        }
    },
    {
        'theme': 'Cocina internacional',
        'scores': {
            'Valentina': {'judge_1': 8, 'judge_2': 9, 'judge_3': 9},
            'Mateo': {'judge_1': 7, 'judge_2': 6, 'judge_3': 7},
            'Camila': {'judge_1': 9, 'judge_2': 8, 'judge_3': 8},
            'Santiago': {'judge_1': 8, 'judge_2': 9, 'judge_3': 7},
            'Lucía': {'judge_1': 7, 'judge_2': 7,'judge_3': 8},
        }
    },
    {
        'theme': 'Final libre',
        'scores': {
            'Valentina': {'judge_1': 9, 'judge_2': 8, 'judge_3': 9},
            'Mateo': {'judge_1': 8, 'judge_2': 9, 'judge_3': 8},
            'Camila': {'judge_1': 7, 'judge_2': 7, 'judge_3': 7},
            'Santiago': {'judge_1': 9, 'judge_2': 9, 'judge_3': 9},
            'Lucía': {'judge_1': 8, 'judge_2': 8, 'judge_3': 7},
        }   
    }
]

print(pr.print_round(rounds[0])) # Imprime la información de la ronda 1 utilizando la función print_round

# Cosas a tener en cuenta: 
    # Rondas = Lista de diccionarios, cada diccionario representa una ronda con un tema y los puntajes de cada participante
    # Ronda = diccionario con theme y scores como clave
    # Scores = diccionario con nombre de participante como clave y otro diccionario con los puntajes de cada juez como valor

# lo voy a separar por rondas, para que sea más fácil de entender.
# ronda 1: Entrada



#for participant, scores in rounds[0]['scores'].items():
 #   print(f"{participant}: {scores}") # Imprime el nombre del participante y sus puntajes en la ronda 1
  #  print(f"la participante {participant} obtuvo un puntaje de {participant.items()}") # Imprime el nombre del participante y sus puntajes en la ronda 1


# print(rounds[0]['scores'].values()) # Imprime el tipo de dato del puntaje de Valentina en la ronda 1

# for participant, scores in rounds[0]['scores'].items():
#     print(f"{participant}: {scores}") # Imprime el nombre del participante y sus puntajes en la ronda 1
#     print(f"la participante {participant} obtuvo un puntaje de {sum(scores.values())}") # Imprime el nombre del participante y sus puntajes en la ronda 1
    
# total = [[participant, sum(scores.values())] for participant, scores in rounds[0]['scores'].items()]
# total
# Out:
# asdasd
# Resultados de la ronda:
# Tema: Entrada
# Valentina: {'judge_1': 8, 'judge_2': 7, 'judge_3': 9}
# Mateo: {'judge_1': 7, 'judge_2': 8, 'judge_3': 7}
# Camila: {'judge_1': 9, 'judge_2': 9, 'judge_3': 8}
# Santiago: {'judge_1': 6, 'judge_2': 7, 'judge_3': 6}
# Lucía: {'judge_1': 8, 'judge_2': 8, 'judge_3': 8}
# None
