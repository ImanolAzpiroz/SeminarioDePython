# %% [markdown]
# ### Ejercicio 1)
#
# La cantidad total de líneas. <br>
# La cantidad total de palabras. <br>
# El promedio de palabras por línea. <br>
# Todas las líneas cuya cantidad de palabras esté por encima del promedio

# %%
text = """Beautiful is better than ugly.
Explicit is better than implicit.
Simple is better than complex.
Complex is better than complicated.
Flat is better than nested.
Sparse is better than dense.
Readability counts.
Special cases aren't special enough to break the rules.
Although practicality beats purity.
Errors should never pass silently.
Unless explicitly silenced.
In the face of ambiguity, refuse the temptation to guess.
There should be one-- and preferably only one --obvious way 
to do it.
Although that way may not be obvious at first unless you're 
Dutch.
Now is better than never.
Although never is often better than *right* now.
If the implementation is hard to explain, it's a bad idea.
If the implementation is easy to explain, it may be a good 
idea.
Namespaces are one honking great idea -- let's do more of 
those!"""

lines = text.splitlines()
lines_total = len(lines)

words_total = len(text.split())
average_words_per_line = words_total / lines_total


print(f'The text contains {words_total} words.')
print(f'The text contains {lines_total} lines.')
print(f'On average, there are {average_words_per_line:.2f} words per line.')

# Forma no pythonica
for line in lines:
    words_in_line = len(line.split())
    if words_in_line > average_words_per_line:
        print(f'"{line}" has more words than the average ({words_in_line} words).')

# Con list comprehension
#                    |Operacion|                    |Variable|  |Iterador|               |Condicion|
result = [f'"{sen}" has more words than the average.' for sen in lines if len(sen.split()) > average_words_per_line]
result
# Out:
# The text contains 137 words.
# The text contains 23 lines.
# On average, there are 5.96 words per line.
# "Special cases aren't special enough to break the rules." has more words than the average (9 words).
# "In the face of ambiguity, refuse the temptation to guess." has more words than the average (10 words).
# "There should be one-- and preferably only one --obvious way " has more words than the average (10 words).
# "Although that way may not be obvious at first unless you're " has more words than the average (11 words).
# "Although never is often better than *right* now." has more words than the average (8 words).
# "If the implementation is hard to explain, it's a bad idea." has more words than the average (11 words).
# "If the implementation is easy to explain, it may be a good " has more words than the average (12 words).
# "Namespaces are one honking great idea -- let's do more of " has more words than the average (11 words).
# ...
