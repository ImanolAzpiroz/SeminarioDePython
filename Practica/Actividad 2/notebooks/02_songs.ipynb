# %%
import sys 
sys.path.append('../src')

# %%
playlist = [
    {"title": "Bohemian Rhapsody", "duration": "5:55"},
    {"title": "Hotel California", "duration": "6:30"},
    {"title": "Stairway to Heaven", "duration": "8:02"},
    {"title": "Imagine", "duration": "3:07"},
    {"title": "Smells Like Teen Spirit", "duration": "5:01"},
    {"title": "Billie Jean", "duration": "4:54"},
    {"title": "Hey Jude", "duration": "7:11"},
    {"title": "Like a Rolling Stone", "duration": "6:13"},
]

# Obtengo las duraciones de las canciones en str
durations = [song["duration"] for song in playlist]

print(durations)  


mins = sum(int(min.split(':')[0]) for min in durations)
secs = sum(int(min.split(':')[1]) for min in durations)

total = sum(int(min.split(':')[0]) * 60 + int(min.split(':')[1]) for min in durations)

print(f'Total duration: {total / 60:.1f} minutes.')
print(f'Total duration: {(mins * 60 + secs) / 60:.1f} seconds.')

print(pot.pot(9))
# Out:
# ['5:55', '6:30', '8:02', '3:07', '5:01', '4:54', '7:11', '6:13']
# Total duration: 46.9 minutes.
# Total duration: 46.9 seconds.
# 81
